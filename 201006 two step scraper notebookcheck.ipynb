# %% [markdown]
# # Two step scraper for notebookcheck.net
#
# Not sure why, but my friend A. developed an interest for notebookcheck.net. He wanted to scrape this website. I figured other new-to-scraping-folks like yourself might want to come along. ;)
#
# **Goal**
# Collect data for every reviewed device.

# %% [markdown]
# ## setup

# %%
import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import csv

# %% [markdown]
# ## collect links (1st scraper)
#
# **Goal**
# Collect links to review for 500 reviewed devices.

# %%
# request webpage, save request to r
r = requests.get('https://www.notebookcheck.net/Reviews.55.0.html?&items_per_page=5000&hide_youtube=1&ns_show_num_normal=250&hide_external_reviews=1&tagArray[]=10&typeArray[]=1',
                timeout=15)

# %%
# create soup variable that contains all html from r
soup = BeautifulSoup(r.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="TYPO3 CMS" name="generator"/>
# <meta content="INDEX,FOLLOW" name="ROBOTS"/>
# <meta content="Our latest laptop and notebook reviews." name="description"/>
# <meta content="en" name="content-language"/>
# <meta content="laptop review, laptop reviews, notebook, benchmarks, tests, measurements, unbiased,notebook, laptop, review, reviews, tests, test, reports, netbook, benchmarks, graphics card, processor" name="keywords"/>
# <link href="typo3temp/Assets/828466e0e7.css?1484583930" media="all" rel="stylesheet" type="text/css"/>
# <link href="typo3temp/Assets/ac5d5618a8.css?1473768586" media="all" rel="stylesheet" type="text/css"/>
# <link href="fileadmin/templates/nbc_v4_4/notebookcheck_new.css?1596812164" media="all" rel="stylesheet" type="text/css"/>
# <link href="fileadmin/templates/js/fancybox2/source/jquery.fancybox.min.css?1419431048" media="all" rel="stylesheet" type="text/css"/>
# <link href="fileadmin/templates/js/fancybox2/source/helpers/jquery.fancybox-thumbs.min.css?1419430926" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js" type="text/javascript"></script>
# <script src="fileadmin/templates/js/fancybox2/source/jquery.fancybox.pack.js?1371172348" type="text/javascript"></script>
# <script src="fileadmin/templates/js/fancybox2/source/helpers/jquery.fancybox-thumbs.pack.js?1419349608" type="text/javascript"></script>
# <script src="typo3temp/Assets/dd82474708.js?1473768586" type="text/javascript"></script>
# <title>Reviews - NotebookCheck.net Reviews</title><link href="/fileadmin/templates/nbc_v4_4/images/logo_nbc_small_shaded.svg" rel="icon" sizes="any" type="image/svg+xml">
# <link href="/fileadmin/templates/nbc_v4_4/images/logo_nbc_small_192px.png" rel="icon" sizes="192x192" type="image/png">
# <link href="/logo_nbc_small_shaded_rectangular_180px.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/fileadmin/templates/nbc_v4_4/images/favicon.ico" rel="icon" type="image/ico">
# <link href="/fileadmin/templates/nbc_v4_4/images/favicon.ico" rel="shortcut icon" type="image/ico">
# <link href="/fileadmin/templates/nbc_v4_4/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/fileadmin/templates/nbc_v4_4/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest" rel="manifest"/>
# <link color="red" href="logo_nbc_small_bw_touchicon.svg" rel="mask-icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="06.10.2020 20:36" name="nbc_data_cached"><style>
# #snigel-cmp-framework .sn-b-def.sn-blue {color: #ffffff!important;background-color: #af0e0e!important;border-color: #af0e0e!important;}
# #snigel-cmp-framework .sn-b-def { border-color: #af0e0e!important;color: #af0e0e!important;}
# #snigel-cmp-framework .sn-selector ul li { color: #af0e0e!important}
# #snigel-cmp-framework .sn-selector ul li:after { background-color: #af0e0e!important; }
# #snigel-cmp-framework .sn-footer-tab .sn-privacy a {color:#af0e0e!important;}
# #snigel-cmp-framework .sn-arrow:after, #snigel-cmp-framework .sn-arrow:before { background-color: #af0e0e!important; }
# #snigel-cmp-framework .sn-switch input:checked+span::before { background-color: #af0e0e!important; }
# #adconsent-usp-link {border: 1px solid #af0e0e!important;color: #af0e0e!important;}
# #adconsent-usp-banner-optout input:checked+.adconsent-usp-slider {background-color:#af0e0e!important;}
# #adconsent-usp-banner-btn {color:#ffffff;border: solid 1px #af0e0e!important;background-color: #af0e0e!important;}
# </style>
# <script src="//staging-cdn.snigelweb.com/adconsent/adconsent.js" type="text/javascript"></script>
# <script>
# //window.__cmp('setLogo', "//www.notebookcheck.net/fileadmin/templates/images/newsstream_logo.png", function(result){});
# window.__cmp('setLogo', "//www.notebookcheck.net/fileadmin/templates/nbc_v4_4/images/header_bg.svg", function(result){});
# window.__cmp('setPrivacyPolicy', "//www.notebookcheck.net/Contact.270.0.html", function(result){});
#
# // non critical visitors
# var nbc_offset = new Date().getTimezoneOffset(); // time offset from UTC in minutes
# console.log('TimezoneOffset:'+nbc_offset);
# if ((typeof nbc_offset === 'string' || nbc_offset instanceof String) && nbc_offset.indexOf('UTC')===0) console.log("timezone critical, start consent tool");
# else if (nbc_offset<-240 || nbc_offset>60) {
#     snhb.options.gdpr.disableDetectEEA = true;
#     console.log('timezone offset of '+nbc_offset+' ok, do not show consent tool');
# }
# </script>
# <script>
# var googletag = googletag || {}; googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//www.googletagservices.com/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
#
# var snhb = snhb || {}; snhb.queue = snhb.queue || [];
#
# function nbc_pagecall() {
#   // get and set pagecall cookie
#   var cookie = document.cookie.split(";");
#   var call = 0;
#   for(var i=0; i<cookie.length; i++) {
#     var c = cookie[i];
#     while (c.charAt(0)==' ') c = c.substring(1);
#     if (c.indexOf("nbc_call=") == 0) call = c.substring(9,c.length);
#   }
#   call = parseInt(call);
#   call++;
#   if (call>2) call=3; // only 1, 2 or 3 as options
#   // set custom targeting for dfp
#   googletag.cmd.push(function() {googletag.pubads().setTargeting("pagecall", String(call));});
#   // save cookie
#   var expires = new Date();
#   var days = 1;
#   expires.setTime(expires.getTime() + (days*24*60*60*1000));
#   document.cookie="nbc_call="+call+";expires="+expires.toUTCString()+";path=/";
#   console.log("pagecall set to "+call);
# }
# </script>
# <script async="" src="//cdn.tech426.com/pub/notebookcheck.net/20200122/snhb-notebookcheck.net.min.js" type="text/javascript"></script>
# <script>
# var node = document.getElementsByTagName('script')[0];
# var abScript = document.createElement('script');
# if (Math.random() < 0.5) {
# abScript.defer = true;
# abScript.src = 'https://snigelweb-com.videoplayerhub.com/videoloader.js';
# } else {
# abScript.async = true;
# abScript.src = 'https://mrb.upapi.net/org?o=5658536637890560&uponit=true&upapi=true';
# }
# node.parentNode.insertBefore(abScript, node);
# // snigel end
#
# googletag.cmd.push(function() {
#
# googletag.pubads().collapseEmptyDivs(true);
# googletag.pubads().enableSingleRequest();
# googletag.pubads().disableInitialLoad();
#
# var additionalAdSlots = [];
#
# var mapping_billb = googletag.sizeMapping().
# addSize([320, 200], [320, 100]).
# addSize([728, 200], [728, 90]).
# addSize([800, 300], [[800, 250],[728, 90]]).
# addSize([970, 300], [[970, 250],[970, 90],[800, 250],[728, 90]]).
# addSize([1100, 500], [[1100, 300],[970, 250],[970, 90],[800, 250],[728, 90]]).build();
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_Billboard', [[320, 100], [728, 90], [800, 250], [970, 90], [970, 250], [1100, 300]], 'div-gpt-ad-1414573626553-0').defineSizeMapping(mapping_billb).addService(googletag.pubads()));
#
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_ContentAd', [[180, 150], [234, 60], [336, 280], [300, 250], [292, 30], [88, 31], [300, 50], [300, 31], [120, 60], [300, 100]], 'div-gpt-ad-1414573626553-1').addService(googletag.pubads()));
# //googletag.defineSlot('/1066427/OL_LowerMainframe', [336, 100], 'div-gpt-ad-1414573626553-4').addService(googletag.pubads());
# googletag.defineSlot('/1066427/OL_InContent', ['fluid'], 'div-gpt-ad-1587636523902-0').addService(googletag.pubads());
#
# var mapping_skys = googletag.sizeMapping().
# addSize([0, 0], []).
# addSize([1220, 500], [160, 600]).
# addSize([1500, 500], [[300, 1050],[300, 600],[300, 250],[160, 600]]).build();
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_Skyscraper', [[160, 600], [300, 1050], [300, 600], [300, 250]], 'div-gpt-ad-1414573626553-6').defineSizeMapping(mapping_skys).addService(googletag.pubads()));
#
# var mapping_topb = googletag.sizeMapping().
# addSize([0,0], [[320,100],[320,50],[300,50]]).
# addSize([468,200], [[468,60],[320,100],[320,50],[300,50]]).
# addSize([728,200], [[728,90],[468,60],[320,100],[320,50],[300,50]]).
# addSize([1100,200], [[970,90],[728,90],[1100,150],[468,60],[320,100],[320,50],[300,50]]).build();
# //googletag.defineSlot('/1066427/OL_Topbanner', [[320,100],[320,50],[300,50],[728,90],[970,90],[1100,150]],'div-gpt-ad-1414573626553-7').defineSizeMapping(mapping_topb).addService(googletag.pubads());
#
# var mapping_mainframe = googletag.sizeMapping().
# addSize([0, 0], [[200, 200],[320, 50],[300, 50]]).
# addSize([728, 200], [[300, 250], [336, 280], [250, 360], [200, 200], [320, 50], [300, 50]]).
# addSize([1100, 200], [[240,400], [300, 600], [160, 600], [728, 200], [300, 250], [336, 280], [250, 360], [200, 200], [320, 50], [300, 50]]).build();
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_MidMainframe', [[200, 200], [240, 400], [250, 360], [300, 250], [300, 600], [336, 280], [160, 600], [320, 50], [300, 50]], 'div-gpt-ad-1414573626553-5').defineSizeMapping(mapping_mainframe).addService(googletag.pubads()));
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_MidMainFrame2', [[200, 200], [240, 400], [250, 360], [300, 250], [300, 600], [336, 280], [160, 600], [320, 50], [300, 50]], 'div-gpt-ad-1414573626553-8').defineSizeMapping(mapping_mainframe).addService(googletag.pubads()));
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_MidMainFrame3', [[200, 200], [240, 400], [250, 360], [300, 250], [300, 600], [336, 280], [160, 600], [320, 50], [300, 50]], 'div-gpt-ad-1414573626553-9').defineSizeMapping(mapping_mainframe).addService(googletag.pubads()));
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_LowestMainFrame', [300, 250], 'div-gpt-ad-1414573626553-14').defineSizeMapping(mapping_mainframe).addService(googletag.pubads()));
# //googletag.defineOutOfPageSlot('/1066427/OL_OutOfPage', 'div-gpt-ad-1414573626553-10').addService(googletag.pubads());
#
# var mapping_leftb = googletag.sizeMapping().
# addSize([0, 0], []).
# addSize([1450, 500], [[120, 700],[120, 600],[160, 600]]).build();
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_LeftBanner', [[120, 600], [120, 700], [160, 600]], 'div-gpt-ad-1414573626553-11').defineSizeMapping(mapping_leftb).addService(googletag.pubads()));
#
# var mapping_lowerads = googletag.sizeMapping().
# addSize([0,0], [[220,90],[250,250],[300,50],[300,100],[320,100]]).
# addSize([728,300], [[220,90],[250,250],[300,50],[300,100],[320,100],[468,60],[728,90]]).
# addSize([1100,300], [[220,90],[250,250],[300,50],[300,100],[320,100],[468,60],[728,90],[750,100],[750,200],[750,300],[764,100],[930,180],[970,90],[970,250],[1100,300]]).build();
# additionalAdSlots.push(googletag.defineSlot('/1066427/OL_LowerAd', [[220,90],[250,250],[300,50],[300,100],[320,100],[468,60],[728,90],[750,100],[750,200],[750,300],[764,100],[930,180],[970,90],[970,250],[1100,300]], 'div-gpt-ad-1414573626553-3').defineSizeMapping(mapping_lowerads).addService(googletag.pubads()));
# //googletag.defineSlot('/1066427/lowerad2', [[220,90],[250,250],[300,50],[300,100],[320,100],[468,60],[728,90],[750,100],[750,200],[750,300],[764,100],[930,180],[970,90],[970,250],[1100,300]], 'div-gpt-ad-1414573626553-12').defineSizeMapping(mapping_lowerads).addService(googletag.pubads());
# additionalAdSlots.push(googletag.defineSlot('/1066427/footertag', [[220,90],[250,250],[300,50],[300,100],[320,100],[468,60],[728,90],[750,100],[750,200],[750,300],[764,100],[930,180],[970,90],[970,250],[1100,300]], 'div-gpt-ad-1414573626553-13').defineSizeMapping(mapping_lowerads).addService(googletag.pubads()));snhb.queue.push(function(){
#  snhb.addAdditionalAdSlotsToRefresh(additionalAdSlots);
# });
#
# googletag.enableServices();
#
# });
#
# nbc_pagecall();
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
# googletag.pubads().setTargeting("pageuid", "55");
# googletag.pubads().setTargeting("domain", "https://www.notebookcheck.net/");
# googletag.pubads().setTargeting("language", "en");
# googletag.pubads().setTargeting("layout", "2");
# googletag.pubads().setTargeting("pagetype", "0");
# });
# </script>
# <meta content="article" property="og:type">
# <meta content="Reviews" property="og:title">
# <meta content="Our latest laptop and notebook reviews." property="og:description">
# <meta content="en_US.UTF-8" property="og:locale">
# <meta content="Notebookcheck" property="article:author">
# <meta content="Notebookcheck" property="og:site_name">
# <meta content="https://www.notebookcheck.net/Reviews.55.0.html" property="og:url">
# <script type="application/ld+json">{
# 	"@context": "http://schema.org/",
# 	"@type": "Article",
# 	"mainEntityOfPage": "https://www.notebookcheck.net/Reviews.55.0.html",
# 	"headline": "Reviews",
# 	"datePublished": "2005-09-12",
# 	"dateModified": "2019-11-20",
# 	"description": "Our latest laptop and notebook reviews.",
# 	"author": "Notebookcheck",
# 	"publisher": {
#     	"@type": "Organization",
#     	"logo": {
#       	"@type": "ImageObject",
#       	"url": "https://www.notebookcheck.com/fileadmin/templates/images/nbc_logo_small.png"
#     },
#     "name": "Notebookcheck"
#   }
# }</script>
# <script>
# jQuery.noConflict();
# jQuery(document).ready(function() {
#  jQuery('a.lightbox').fancybox({
#   prevEffect  : 'none',
#   nextEffect  : 'none',
#   padding:0,
#   helpers  : {
#    title  : {
#     type: 'outside'
#    },
#    thumbs  : {
#     width  : 50,
#     height  : 50
#    },
#   },
#   beforeLoad: function() {
#    var el, id = jQuery(this.element).data('title-id');
#    if (id) {
#     el = jQuery('#' + id);
#
#     if (el.length) {
#      this.title = el.html();
#     }
#    }
#   }
#  });
# });
# </script><script>
# function toggleMe(a){
# var e=document.getElementById(a);
# if(e.style.display=="none" || e.style.maxHeight!=""){
#  e.style.display="block";
#  e.style.maxHeight="";
#  if (document.getElementById(a+"_a1")) document.getElementById(a+"_a1").style.display="none";
#  if (document.getElementById(a+"_a2")) document.getElementById(a+"_a2").style.display="";
#  if (document.getElementById(a+"_gr")) document.getElementById(a+"_gr").style.display="none";
# } else {
#  e.style.display="none";
#  if (document.getElementById(a+"_a1")) document.getElementById(a+"_a1").style.display="";
#  if (document.getElementById(a+"_a2")) document.getElementById(a+"_a2").style.display="none";
#  if (document.getElementById(a+"_gr")) document.getElementById(a+"_gr").style.display="";
# }
# return false;}
# </script><link href="https://www.notebookcheck.net/Reviews.55.0.html" rel="canonical">
# <link href="https://www.notebookcheck.net/RSS-Feed-Notebook-Reviews.8156.0.html" rel="alternate" title="Notebookcheck Reviews" type="application/rss+xml">
# <link href="https://www.notebookcheck.net/News.152.100.html" rel="alternate" title="Notebookcheck News" type="application/rss+xml">
# <meta content="width=device-width, initial-scale=1" name="viewport"/><script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-112820-1', 'auto');
# ga('set', 'anonymizeIp', true);
# ga('send', 'pageview', {'dimension2':'Notebookcheck','dimension3':'0','dimension4':'','dimension5':'0'});</script>
# <style type="text/css">
# 	.nbc-right-float {}
# @media only screen and (max-width: 764px)  {
# 	.nbc-right-float-inline {margin-right:0px;}
# 	.nbc-right-float-hide {display:none;}
# }
# @media only screen and (max-width: 500px)  {
# 	.nbc-right-float-inline {float:none; }
# }
#
# </style>
# <style type="text/css">.introa_img_large {border:none;width:100%;max-width:168px;max-height:126px;height:auto;vertical-align:top}.introa_img_med {border:none;width:100%;max-width:120px;max-height:90px;height:auto;vertical-align:top}.introa_img_small {border:none;width:100%;max-width:60px;max-height:45px;height:auto;vertical-align:top}.introa_medium a,.introa_medium a.visited,.introa_whole a,.introa_whole a:visited{color:#000}.introa_img_huge{border:none;height:auto;width:100%}.introa_whole{margin:0;padding:0;font-size:.89em;overflow:hidden;position:relative}.introa_whole img{border:0}.introa_whole h2{font-weight:700;margin-left:0!important;margin-right:0!important}.introa_title{margin:0;font-weight:400;font-size:1em;letter-spacing:normal;display:block;width:100%}.introa_title .rating{font-size:1.2em}.introa_huge{margin-top:22px;margin-bottom:22px;clear:left;overflow:hidden;display:table;padding:3px;min-width:50%}.introa_large,.introa_medium,.introa_small{padding:2px;min-width:50%;display:block;overflow:hidden;clear:left}.introa_huge h2{font-size:1.2em;margin-bottom:3px;text-align:center}.introa_large{margin-top:25px;margin-bottom:25px;border:1px solid #ffffff00}.introa_large:hover{border:1px solid rgba(0,0,0,0.03);background:rgba(0,0,0,0.02)}.introa_large h2{font-size:1.3em;margin-bottom:3px;border-bottom:4px solid rgba(0,0,0,0.08)}.introa_medium{margin-top:25px;margin-bottom:25px;border:1px solid #ffffff00}.introa_medium:hover{border:1px solid rgba(0,0,0,0.03);background:rgba(0,0,0,0.02)}.introa_medium h2{font-size:1.1em;margin-bottom:1px;font-weight:700}.introa_small{color:#666;margin-top:8px;margin-bottom:8px;border:1px solid #ffffff00}.introa_small .introa_rm_text{color:#666}.introa_small:hover{border:1px solid rgba(0,0,0,0.03);background:rgba(0,0,0,0.02)}.introa_review_specs{font-style:italic;color:#fff}.introa_review_specs_med{color:#afafaf;font-weight:300}.introa_rl_box,.introa_rl_title{background-color:#333;opacity:.9;color:#fff}.introa_rl_hoverable{display:block;position:relative;width:100%}.introa_rl_texts{position:absolute;bottom:0;left:0;width:100%}.introa_rl_title{font-size:1.1em;text-align:center;line-height:1.4;width:100%;overflow:hidden}.introa_rl_title_padding{padding:5px}.introa_rl_box{display:none;border-top:1px dashed #fff;padding:5px}.introa_more{background:linear-gradient(to right,rgba(255,255,255,0.5),rgba(255,255,255,1),rgba(255,255,255,1));position:absolute;right:0;top:1.6em;padding-left:0.5em}.introa_l1003{margin:2em 0}.introa_rm_text{float:left;width:75%}.introa_medium .introa_rm_img{overflow:hidden;margin-top:0.4em}.introa_rm_img{width:23%;float:left;margin-right:2%;border:0 solid #afafaf;text-align:right}.introa_fulldate,.introa_fulldate_background{margin-left:-13px;text-shadow:0 1px 0 #FFF,0 -1px 0 #FFF,1px 0 0 #FFF,-1px 0 0 #FFF;padding:2px 4px 0 16px}.introa_medium .introa_rm_header{font-size:1.08em;margin-bottom:1px}.introa_fulldate{position:absolute;color:#333;z-index:100}.introa_fulldate_new{text-align:center;margin-bottom:-15px;color:#777}.introa_fulldate_ticker{position:relative;clear:left;font-weight:700;margin-top:10px;overflow:hidden}.introa_whole .itemauthordate{text-align:right;color:#999;font-size:0.9em}.introa_whole .itemauthorcolumn{color:#000}.introa_ers,.introa_other{margin-top:5px;margin-bottom:5px;clear:left;overflow:hidden}.introa_fulldate_background{position:absolute;background-color:#efefef;color:#333;border-bottom:1px solid #efdfdf;border-right:1px solid #efdfdf;z-index:99;opacity:.6;height:1.4em}.introa_ers_icon,.introa_newsicon{opacity:.5;vertical-align:middle}.introa_ers{color:#000}.introa_ers_link{color:#666}.introa_ers_link:visited{color:#333}.introa_other{color:#666}.introa_newsicon{border:none}.introa_news_abstract,.introa_rm_abstract{color:#666;float:left;clear:left;position:relative}.introa_icon{vertical-align:middle;float:left;margin-right:2%;width:23%;text-align:right;border:none}.introa_title{float:left;color:#000}.introa_form,.restrictedElements{width:100%;color ...
# <style type="text/css">.socialarea {font-size:1.2em}.socialarea a{color:#fff;display:inline-block;padding:.2em;margin:0 5px;height:2em;border-radius:10%;text-align:center;width:2em}.socialarea a:hover{text-decoration:none}.socialarea img,svg{vertical-align:middle;border:0}.socialarea .share_text{padding:.72em 1em;float:left}.socialarea .share_logo{padding:.1em}a.socialarea_twitter{background-color:#55acee}a.socialarea_twitter:hover{background-color:#32bbf5}a.socialarea_facebook{background-color:#3b5998}a.socialarea_facebook:hover{background-color:#4273c8}</style>
# <script type="text/javascript">var $typo3Path="/";</script><script type="text/javascript">var $sModPath="typo3conf/ext/nbc2bestprice/mod1/</script><script type="text/javascript">var $extPath="typo3conf/ext/nbc2bestprice/";</script><link href="typo3conf/ext/nbc2bestprice/res/bestprice.css?2020100621" rel="stylesheet" type="text/css"><script src="typo3conf/ext/nbc2bestprice/res/bestprice.js?2020100621" type="text/javascript"></script>
# <script type="text/javascript">
# 	var secs
# 	var timerID = null
# 	var timerRunning = false
# 	var delay = 1000
#
# 	var xmlHttp;
#
#
# 	function InitializeTimer()
# 	{
# 	    // Set the length of the timer, in seconds
# 	    secs = 2
# 	    StopTheClock()
# 	    StartTheTimer()
# 	}
#
# 	function StopTheClock()
# 	{
# 	    if(timerRunning)
# 	        clearTimeout(timerID)
# 	    timerRunning = false
# 	}
#
# 	function StartTheTimer()
# 	{
# 	    if (secs==0)
# 	    {
# 	        StopTheClock()
# 	        var model = document.getElementById("model").value;
# 	        var language = document.getElementById("lang").value;
# 			xmlHttp.open("GET","index.php?eID=ajaxsearch&model="+model+"&language="+language,true);
# 			xmlHttp.send(null);
# 	    }
# 	    else
# 	    {
# 	        //document.getElementById("timer").innerHTML = secs;
# 	        self.status = secs
# 	        secs = secs - 1
# 	        timerRunning = true
# 	        timerID = self.setTimeout("StartTheTimer()", delay)
# 	    }
# 	}
#
# 	function ajaxFunction()
# 	{
# 		try
#   		{  // Firefox, Opera 8.0+, Safari
#   			xmlHttp=new XMLHttpRequest();
#   		}
# 		catch (e)
# 		{  // Internet Explorer
#   			try
#     		{
#     			xmlHttp=new ActiveXObject("Msxml2.XMLHTTP");
#     		}
#   			catch (e)
#     		{
#     			try
#       			{
#       				xmlHttp=new ActiveXObject("Microsoft.XMLHTTP");
#       			}
#     			catch (e)
#       			{
# 			    	alert("Your browser does not support AJAX!");
# 			    	return false;
#       			}
#     		}
#   		}
#   		xmlHttp.onreadystatechange=function()
#     	{
#      		switch (xmlHttp.readyState) {
# 		  		case 1:
# 		    		//document.getElementById("state").innerHTML = "State:"+xmlHttp.readyState+" - The request has been set up";
# 		    		break;
# 		  		case 2:
# 		    		//document.getElementById("state").innerHTML = "State:"+xmlHttp.readyState+" - The request has been sent";
# 		    		break;
# 		  		case 3:
# 		    		//document.getElementById("state").innerHTML = "State:"+xmlHttp.readyState+" - The request is in process";
# 		    		break;
# 		  		case 4:
# 				    document.getElementById("response").innerHTML = ""+xmlHttp.responseText+"";
# 				    document.getElementById("loading_gif").style.display = "none";
# 		    		break;
# 		  		default:
# 		    		//document.getElementById("state").innerHTML = "State:"+xmlHttp.readyState+" - Unknown State";
# 		    		break;
# 			}
#     	}
#    		document.getElementById("loading_gif").style.display = "";
#      	InitializeTimer();
#
#   	}
#
# 	// Check if form was alredy submitted
#    script_ended = 0;
#    function jumpToUrl(URL)   {
#       document.location = URL;
#    }
#
# 	var submitted;
# 	submitted = false;
#
# 	function CheckSubmit() {
# 		if (submitted == false) {
# 			submitted = true;
# 			return true;
# 		} else {
# 			alert("Search in progress - Please wait until the page has reloaded!");
# 			return false;
# 		}
# 	}
# 			</script>
# <script language="JavaScript" type="text/javascript">
# 			 <!--
# 				function nbcompare_createCookie(name,value,days) {
# 					if (days) {
# 						var date = new Date();
# 						date.setTime(date.getTime()+(days*24*60*60*1000));
# 						var expires = "; expires="+date.toGMTString();
# 					}
# 					else var expires = "";
# 					document.cookie = name+"="+value+expires+"; path=/";
# 				}
#
# 				function nbcompare_readCookie(name) {
# 					var nameEQ = name + "=";
# 					var ca = document.cookie.split(';');
# 					for(var i=0;i < ca.length;i++) {
# 						var c = ca[i];
# 						while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 						if (c.indexOf(nameEQ) == 0) return c.substring(nameEQ.length,c.length);
# 					}
# 					return null;
# 				}
#
# 				function nbcompare_eraseCookie(name) {
# 					nbcompare_createCookie(name,"",-1);
# 				}
#
# 				function nbcompare_addSpecs(specsid,name) {
# 					// read cookie
# 					cookievar = nbcompare_readCookie("nbc_nbcompare");
# 					cookievar_names = nbcompare_readCookie("nbc_nbcompare_names");
#
# 					if (specsid) {
# 						cookievar += ","+specsid;
# 						cookievar_names += ","+name;
# 						//nbcompare_createCookie("nbc_nbcompare",cookievar,7);
# 					}
# 					var newcookievar = "";
# 					var querystring = ""
# 					var count=0;
# 					if (cookievar) {
# 						var ca = cookievar.split(',');
# 						var newarray = [];
# 						for(var i=0;i < ca.length;i++) {
# 							var c = ca[i];
# 							if (c>0 && jQuery.inArray(c, newarray)==-1) {
# 								if (newarray.length>0) newcookievar += ","
# 								newcookievar += c;
# 								newarray.push(c);
# 								querystring += "&specs[]="+c;
# 								count++;
# 							}
# 						}
# 					} // empty array
# 					nbcompare_createCookie("nbc_nbcompare",newcookievar,7);
# 					jQuery("#nbc_nbcompare_link_number").html(count);
# 					jQuery("#nbc_nbcompare_count").html(newcookievar);
# 					jQuery("#nbc_nbcompare_link").attr("href", "/index.php?id=127065"+querystring);
#
# 					return false; // to not follow the original link
# 				} // nbcompare_addSpecs
#
# 				function nbcompare_removeAllSpecs() {
# 					nbcompare_eraseCookie("nbc_nbcompare");
# 					nbcompare_addSpecs(null);
#
# 					return false; // to not follow the original link
# 				} // nbcompare_removeAllSpecs
#
# 				function nbcompare_removeSpecs(specsid) {
# 					// read cookie
# 					cookievar = nbcompare_readCookie("nbc_nbcompare");
# 					var newcookievar = "";
# 					var querystring = ""
# 					var count=0;
# 					if (cookievar) {
# 						var ca = cookievar.split(',');
# 						var newarray = [];
# 						for(var i=0;i < ca.length;i++) {
# 							if (ca[i]==specsid) pos = i;
# 						}
# 						//alert(cookievar+" / "+specsid+" / "+pos);
# 						for(var i=0;i < ca.length;i++) {
# 							var c = ca[i];
# 							if (c>0 && i!=pos) {
# 								if (newarray.length>0) newcookievar += ","
# 								newcookievar += c;
# 								newarray.push(c);
# 								querystring += "&specs[]="+c;
# 								count++;
# 							} // if
# 						} // for
# 					} // empty array
# 					nbcompare_createCookie("nbc_nbcompare",newcookievar,7);
# 					jQuery("#nbc_nbcompare_link_number").html(count);
# 					jQuery("#nbc_nbcompare_count").html(newcookievar);
# 					jQuery("#nbc_nbcompare_link").attr("href", "/index.php?id=73542"+querystring);
#
# 					return true;
# 				} // nbcompare_removeSpecs
#
# 				jQuery(document).ready(function() {
# 					nbcompare_addSpecs(null);
# 				});
# 			 //-->
# 			</script>
# <script type="text/javascript">/* jQuery Unveil, MIT license, Luís Almeida */;(function(jQuery){jQuery.fn.unveil=function(threshold,callback){var $w=jQuery(window),th=threshold||0,retina=window.devicePixelRatio>1,attrib=retina?"data-src-retina":"data-src",images=this,loaded;this.one("unveil",function(){var source=this.getAttribute(attrib);source=source||this.getAttribute("data-src");if(source){this.setAttribute("src",source);if(typeof callback==="function")callback.call(this);}});function unveil(){var inview=images.filter(function(){var $e=jQuery(this),wt=$w.scrollTop(),wb=wt+$w.height(),et=$e.offset().top,eb=et+$e.height();return eb>=wt-th&&et<=wb+th;});loaded=inview.trigger("unveil");images=images.not(loaded);}$w.scroll(unveil);$w.resize(unveil);unveil();return this;};})(window.jQuery||window.Zepto);jQuery(document).ready(function() {jQuery("img.lazy").unveil(200);});</script>
# </link></link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></link></link></link></link></head>
# <body>
# <div id="background-click-layer"></div>
# <div id="nbc_main">
# <div id="nbc_topb"></div>
# <div id="nbc_skys"><div id="div-gpt-ad-1414573626553-6">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-6'); });
# </script>
# </div>
# <div id="toc"></div></div>
# <div id="nbc_leftb"><div id="div-gpt-ad-1414573626553-11" style="float:right">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-11'); });</script>
# <span class="bt-uid-tg" data-uid="5b19498fe4-158" style="display: none !important"></span>
# </div></div>
# <div id="nbc_topbar"><a href="/" id="nbc_logotop" title="Notebookcheck Home">Notebookcheck</a></div>
# <div id="nbc_menubar">
# <div id="navigation_logo_bottom"><a href="/" id="nbc_logobottom" title="Notebookcheck Home"> </a></div>
# <div id="navigation"><ul><li class="mainmenu selected"><a href="Reviews.55.0.html">Reviews</a></li><li class="mainmenu"><a href="News.152.0.html">News</a></li><li class="mainmenu"><a href="Benchmarks-Tech.123.0.html">Benchmarks / Tech</a></li><li class="mainmenu"><a href="Laptop-Buying-Guide-Tool.13212.0.html">Buyers Guide</a></li><li class="mainmenu"><a href="Library.279.0.html">Library</a></li><li class="mainmenu"><a href="Search.8222.0.html">Search</a></li><li class="mainmenu"><a href="Jobs.2095.0.html">Jobs</a></li><li class="mainmenu"><a href="Contact.270.0.html">Contact</a></li><li class="moremenu"><a href="#" onclick="
# var el = document.getElementsByClassName('mainmenu');
# for (var i = 0, len = el.length; i &lt; len; i++) el[i].style.display='block';
# this.parentNode.style.display='none';
# return false;
# ">...</a></li>
# <li>
# <a href="https://www.notebookcheck.net/Google-Search.36690.0.html" onclick="
#   jQuery('#nbc_searchbar2').toggle(100);
#   document.getElementById('nbc_searchbar_field2').focus();
#   return false;
#   ">
# <img alt="search" src="fileadmin/templates/nbc_v4_4/images/lupe_weiss.svg" style="width:1em;height:1em;border:0;"/>
# </a>
# </li>
# <li>
# <a href="#footer" onclick="jQuery('#langcontainer').toggle(100); return false;"><img alt="open" src="fileadmin/templates/images/arrow_down_white.svg" style="width:0.8em;height:0.8em;border:0"/> <img alt="EN" src="/fileadmin/templates/images/svg_flags/us.svg" style="width:auto;height:0.8em"/></a>
# </li>
# </ul>
# <div id="nbc_searchbar2">
# <form action="https://www.notebookcheck.net/Google-Search.36690.0.html" id="cse-search-box" style="margin:0px;padding:3px;">
# <input name="cx" type="hidden" value="partner-pub-9323363027260837:txif1w-xjer"/>
# <input name="cof" type="hidden" value="FORID:10"/>
# <input name="ie" type="hidden" value="UTF-8"/>
# <input id="nbc_searchbar_field2" name="q" size="16" type="text"/>
# <button id="nbc_searchbar_button2" name="sa" type="submit"></button>
# <a href="https://www.notebookcheck.net/Google-Search.36690.0.html" onclick="
#   jQuery('#nbc_searchbar2').toggle(100);
#   return false;
#   " style="line-height:1em;color:#333;">X</a>
# </form>
# </div>
# <div id="langcontainer">
# <ul>
# <li><a class="langlink" href="https://www.notebookcheck.com/"><img alt="DE" src="/fileadmin/templates/images/svg_flags/de.svg"/> Deutsch</a></li>
# <li class="selected"><a class="langlink" href="https://www.notebookcheck.net/"><img alt="US" src="/fileadmin/templates/images/svg_flags/us.svg"/> English</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.org/"><img alt="ES" src="/fileadmin/templates/images/svg_flags/es.svg"/> Español</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.biz/"><img alt="FR" src="/fileadmin/templates/images/svg_flags/fr.svg"/> Français</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.it/"><img alt="IT" src="/fileadmin/templates/images/svg_flags/it.svg"/> Italiano</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.nl/"><img alt="NL" src="/fileadmin/templates/images/svg_flags/nl.svg"/> Nederlands</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.pl/"><img alt="PL" src="/fileadmin/templates/images/svg_flags/pl.svg"/> Polski</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.info/"><img alt="PT" src="/fileadmin/templates/images/svg_flags/pt.svg"/> Português</a></li>
# <li><a class="langlink" href="https://www.notebookcheck-ru.com/"><img alt="RU" src="/fileadmin/templates/images/svg_flags/ru.svg"/> Русский</a></li>
# <li><a class="langlink" href="https://www.notebookcheck-tr.com/"><img alt="TR" src="/fileadmin/templates/images/svg_flags/tr.svg"/> Türkçe</a></li>
# <li><a class="langlink" href="https://www.notebookcheck.se/"><img alt="SE" src="/fileadmin/templates/images/svg_flags/se.svg"/> Svenska</a></li>
# <li><a class="langlink" href="https://www.notebookcheck-cn.com/"><img alt="CN" src="/fileadmin/templates/images/svg_flags/cn.svg"/> Chinese</a></li>
# <li><a class="langlink" href="https://www.notebookcheck-hu.com/"><img alt="HU" src="/fileadmin/templates/images/svg_flags/hu.svg"/> Magyar</a></li>
# </ul>
# </div></div>
# </div>
# <div id="nbc_bb"><div class="header_bar introa_l1002"><script type="text/javascript">
# 				var loading_0 = false; // loading indicator;
# 				var loading_num_0 = 0; // incrementing loading num;
#
# 				jQuery(document).ready(function() {
# 					//jQuery("img").unveil(200);
#
#
#
# 					/*
# 					jQuery(".introa_rl_hoverable").hover(function() {
# 						jQuery(this).children().children(".introa_rl_box").slideToggle(400); // if more than one element is on the page, this is attached more than once for each element
# 					});
# 					*/
#
#
# 					// hide settings (do it in javascript, to show it to browsers without javascript enabled)
# 					//jQuery(".introa_form").slideUp(100);
# 				});
#
# 				function ajaxReload_0(tt_content_uid,page,items_per_page,no_url_change) {
#
# 					if (loading_0==true) { // do not call if already loading
# 						//jQuery("#introa_loading_info_0").html("already loading ...");
# 						//return false;
# 					}
#
# 					loading_0 = true;
#
# 					items_per_page = typeof items_per_page !== "undefined" ? items_per_page : 4;
#
# 					jQuery("#introa_ajax_"+tt_content_uid).html("loading ...");
# 					jQuery("#introa_ajax_"+tt_content_uid).show();
# 					jQuery("#introa_loading_info_"+tt_content_uid).html("loading ...");
# 					//console.log("loading "+items_per_page+" elements ...");
# 					jQuery("#introa_loading_info_"+tt_content_uid).show();
# 					if (jQuery("#introa_content_"+tt_content_uid).length) jQuery("#introa_content_"+tt_content_uid).fadeTo( 250, 0.2);
#
# 					// set default to 0 for the page
# 					page = typeof page !== "undefined" ? page : 0;
#
#
#
# 					var tagArray = new Array();
#
# 					// get checkbox value for the tags
# 					container = document.getElementById("introa_cbox_tag_surround_"+tt_content_uid); // get container div of the checkboxes
# 					if (container) {
# 						inputs = container.getElementsByTagName("input"); // get all input fields in the images div
# 						for (index = 0; index < inputs.length; ++index) {
# 							if(inputs[index].checked) tagArray.push(inputs[index].value);
# 						} // for
# 					} // if container
#
# 					var typeArray = new Array();
#
# 					// get checkbox value for the pagetypes
# 					container = document.getElementById("introa_cbox_type_surround_"+tt_content_uid); // get container div of the checkboxes
# 					if (container) {
# 						inputs = container.getElementsByTagName("input"); // get all input fields in the images div
# 						for (index = 0; index < inputs.length; ++index) {
# 							if(inputs[index].checked) typeArray.push(inputs[index].value);
# 						} // for
# 					} // if container
#
# 					loading_num_0++;
#
# 					var paraArray = {"id":98933,"ns_ajax":1,"language":2
# 						,"loading_num":loading_num_0,"ns_json":1
# 						,"ns_tt_content_uid":0};
# 					/*"ns_page_uid":55,*/
# 					if (items_per_page != 50) paraArray.items_per_page=items_per_page
# 					if(document.getElementById("introa_cbox_ticker_"+tt_content_uid).checked) paraArray.ticker=1;
# 					if(document.getElementById("introa_cbox_tag_or_"+tt_content_uid).checked) paraArray.tag_or=1;
# 					if (1>0) paraArray.hide_date=1;
# 					if (1>0) paraArray.ns_hide_restrictions=1;
# 					if (1002>0) paraArray.ns_layout=1002;
# 					if (1>0) paraArray.hide_youtube=1;
# 					if (0>0) paraArray.order_by_sorting=0;
# 					if (0>0) paraArray.ns_show_hr=0;
# 					if (1>0) paraArray.ns_featured_articles_only=1;
# 					if (0>0) paraArray.ns_hide_navigation_buttons=0;
# 					if (0>0) paraArray.ns_show_num_normal=0;
# 					if (1>0) paraArray.hide_external_reviews=1;
# 					if (0>0) paraArray.ns_article_pid=0;
# 					if ("https://www.notebookcheck.net/") paraArray.ns_img_domain="https://www.notebookcheck.net/";
# 					if (tagArray.length>0) paraArray.tagArray=tagArray;
# 					if (typeArray.length>0) paraArray.typeArray=typeArray;
# 					if (page>0) paraArray.page=page;
# 					var title = jQuery("#introa_search_title_"+tt_content_uid).val();
# 					if (title) paraArray.introa_search_title=title;
#
# 					jQuery("#introa_ajax_"+tt_content_uid).html("loading ...");
# 					jQuery("#introa_ajax_"+tt_content_uid).show();
#
#
# 					jQuery.ajax({url: "//dev1.notebook-check.com/index.php",type: "GET",
# 						/* url: "index.php", */
# 						data: paraArray
# 						})
# 						.done(function(data) {
# 							jQuery("#introa_currently_loaded_0").html(items_per_page);
#
# 							// move google ads
# 							//jQuery("#introa_googleads_0").appendTo("#introa_googleads_temp_0"); // problem - iframe ads are shown too large after moving!
#
# 							try {
# 								obj = JSON.parse(data);
# 							}	catch(e){
# 								console.log(e); //error in the above string(in this case,yes)!
# 							}
#
# 							if (obj.loading_num != loading_num_0) {
# 								console.log("discarded loading #"+obj.loading_num+" as a newer request #"+loading_num_0+" is under way");
# 								return 0;
# 							}
#
#
# 							jQuery("#introa_ajax_"+tt_content_uid).html("");
# 							jQuery("#introa_ajax_"+tt_content_uid).hide();
# 							jQuery("#introa_content_"+tt_content_uid).html(obj.data);
# 							jQuery("#introa_loading_info_"+tt_content_uid).hide();
# 							if (jQuery("#introa_content_"+tt_content_uid).length) jQuery("#introa_content_"+tt_content_uid).fadeTo( 250, 1);
#
# 							// add hover for the new elements
# 							/*
# 							jQuery(".introa_rl_hoverable").hover(function() {
# 								jQuery(this).children().children(".introa_rl_box").slideToggle(400);
# 							});
# 							*/
# 							jQuery(".featured_item").hover(function() {
# 									jQuery(this).children().css("opacity","1");
# 							}, function() {
# 									jQuery(this).children().css("opacity","0.9");
# 							});
# 							// get query string with parameters (ignore ajax parameters)
# 							var queryString = "";
# 							for (var key in paraArray) {
# 								if (key != "id" && key != "ns_ajax" && key != "language"
# 										&& key != "tagArray[]" && key != "tagArray"
# 										&& key != "typeArray[]" && key != "typeArray"
# 										&& key != "loading_num" && key != "ns_json"
# 										&& key != "ns_page_uid" && key != "ns_tt_content_uid") {
# 									if (paraArray[key])	queryString += "&"+key+"="+paraArray[key];
# 								}
# 							}
# 							for (var key in tagArray) { // add tagArray
# 								if (tagArray[key]>0) queryString += "&tagArray[]="+tagArray[key];
# 							}
# 							for (var key in typeArray) { // add typeArray
# 								if (typeArray[key]>0) queryString += "&typeArray[]="+typeArray[key];
# 							}
# 							// change url
# 							var stateObj = { foo: "bar" };
#
# 							// rebind unveil to dynamically load images
# 							//jQuery("img").unveil(200);
#
# 							loading = false;
#
# 						})
# 						.fail(function(data) {
# 							jQuery("#introa_ajax_0").html("loading failed!");
# 							jQuery("#introa_loading_info_0").html("loading failed!");
# 							loading = false;
# 						});
#
# 				} // function ajaxReload
#
# 					jQuery(".featured_item").hover(function() {
# 							jQuery(this).children().css("opacity","1");
# 					}, function() {
# 							jQuery(this).children().css("opacity","0.9");
# 					});
# function convertTime(utctimetoconvert) {
# 	userDate = new Date();
# 	var utcTime = userDate.getTime();
# 	utcTime = Math.round(utcTime/1000);
# 	timeDiff = utcTime-utctimetoconvert;
# 	if (timeDiff<0) result_str = "";
# 	else {
# 		var days = Math.floor(timeDiff / (60 * 60 * 24));
# 		timeDiff -=  days * (60 * 60 * 24);
#
# 		var hours = Math.floor(timeDiff / (60 * 60));
# 		timeDiff -= hours * (60 * 60);
#
# 		var mins = Math.floor(timeDiff / (60));
# 		timeDiff -= mins * (60);
#
# 		var seconds = Math.floor(timeDiff) ;
# 		timeDiff -= seconds;
#
# 		var result_str = "";
# 		if (days>0) {
# 			if (days==1) result_str = days + " day";
# 			else result_str = days + " days";
# 		}
# 		if (days<2) {
# 			if (result_str && hours>0) result_str += ", ";
# 			if (hours>0) {
# 				if (hours==1) result_str += hours + " hour";
# 				else result_str += hours + " hours";
# 			}
# 			if (result_str && mins>0) result_str += ", ";
# 			if (mins>0 && days<1) {
# 				if (mins==1) result_str += mins + " minute";
# 				else result_str += mins + " minutes";
# 			}
# 			if (days==0 && hours==0 && mins<5) {
# 				if (result_str && seconds>0) result_str += ", ";
# 				if (seconds>0) {
# 					if (seconds==1) result_str += seconds + " second";
# 					else result_str += seconds + " seconds";
# 				}
# 			}
# 		}
# 		result_str = " "+result_str+" ago";
# 	}
# 	var x = document.getElementsByClassName("itemdate_"+utctimetoconvert);
# 	var i;
# 	for (i = 0; i < x.length; i++) {
# 			x[i].innerHTML = result_str;
# 	}
# }</script><div class="introa_loading_info" id="introa_loading_info_0"></div><form action="https://www.notebookcheck.net/Reviews.55.0.html" class="introa_form" id="introa_form_0" method="post" name="introa_form" onsubmit="ajaxReload_0(0);return false;" style="display:none;"> <div class="introa_ajax" id="introa_ajax_0"></div><div id="introa_cbox_type_surround_0"><label for="introa_cbox_type_1_0"><input id="introa_cbox_type_1_0" name="typeArray[]" onclick="jQuery('#introa_outer_cbox_type_review_0').prop('checked', this.checked); ajaxReload_0(0);" type="checkbox" value="1"/> Reviews</label>, <label for="introa_cbox_type_4_0"><input id="introa_cbox_type_4_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="4"/> News</label>, <label for="introa_cbox_type_8_0"><input id="introa_cbox_type_8_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="8"/> CPU</label>, <label for="introa_cbox_type_9_0"><input id="introa_cbox_type_9_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="9"/> GPU</label>, <label for="introa_cbox_type_3_0"><input id="introa_cbox_type_3_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="3"/> Articles</label>, <label for="introa_cbox_type_6_0"><input id="introa_cbox_type_6_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="6"/> Columns</label>, <label for="introa_cbox_type_0_0"><input id="introa_cbox_type_0_0" name="typeArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="0"/> Other</label></div> <label for="introa_cbox_tag_or_0"><input id="introa_cbox_tag_or_0" name="tag_or" onclick="ajaxReload_0(0);" type="checkbox" value="1"/>"or"</label> search relation.<div id="introa_cbox_tag_surround_0"><label for="introa_cbox_tag_160_0"><input id="introa_cbox_tag_160_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="160"/>5G</label>, <label for="introa_cbox_tag_15_0"><input id="introa_cbox_tag_15_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="15"/>Accessory</label>, <label for="introa_cbox_tag_32_0"><input id="introa_cbox_tag_32_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="32"/>AMD</label>, <label for="introa_cbox_tag_4_0"><input id="introa_cbox_tag_4_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="4"/>Android</label>, <label for="introa_cbox_tag_13_0"><input id="introa_cbox_tag_13_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="13"/>Apple</label>, <label for="introa_cbox_tag_23_0"><input id="introa_cbox_tag_23_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="23"/>ARM</label>, <label for="introa_cbox_tag_102_0"><input id="introa_cbox_tag_102_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="102"/>Audio</label>, <label for="introa_cbox_tag_5_0"><input id="introa_cbox_tag_5_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="5"/>Business</label>, <label for="introa_cbox_tag_175_0"><input id="introa_cbox_tag_175_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="175"/>Camera</label>, <label for="introa_cbox_tag_116_0"><input id="introa_cbox_tag_116_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="116"/>Cannon Lake</label>, <label for="introa_cbox_tag_31_0"><input id="introa_cbox_tag_31_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="31"/>Charts</label>, <label for="introa_cbox_tag_96_0"><input id="introa_cbox_tag_96_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="96"/>Chinese Tech</label>, <label for="introa_cbox_tag_27_0"><input id="introa_cbox_tag_27_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="27"/>Chromebook</label>, <label for="introa_cbox_tag_104_0"><input id="introa_cbox_tag_104_0" name="tagArray[]" onclick="ajaxReload_0(0);" type="checkbox" value="104"/>Coffee Lake</label>, <label for="introa_cbox_tag_158_0"><input id="introa_cbo ...
# <div id="div-gpt-ad-1414573626553-0">
# <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-0'); });</script>
# </div>
# <span class="bt-uid-tg" data-uid="5b19497bb1-158" style="display: none !important"></span>
# </div></div>
# <div id="nbc_contentcontainer">
# <div id="nbc_contentcolumns_1col">
# <div id="nbc_breadcrumb"></div>
# <div id="nbc_maincontent_1col">
# <div id="content"><div class="ttcl_0 csc-default" id="c631">
# <div class="tx-nbc2fe-incontent-column">
# <div class="nbc-right-float nbc-right-float-inline"><div id="div-gpt-ad-1414573626553-1">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-1'); });
# </script>
# </div>
# <div id="snhb-mobile_top-0"></div></div>
# </div>
# <div class="csc-header csc-header-n1"><h1 class="csc-firstHeader">Reviews</h1></div><p class="bodytext">This category contains objective reviews about notebooks / laptops, smartphones, and tablets tested by Notebookcheck. <span style="line-height: 17px; background-color: rgb(255, 255, 255);">You can also access our latest reviews as an </span><span style="line-height: 17px; background-color: rgb(255, 255, 255);"><a class="internal-link" href="RSS-Feed-Notebook-Reviews.8156.0.html" target="_self">RSS feed here</a></span><span style="line-height: 17px; background-color: rgb(255, 255, 255);">.</span></p></div><div class="ttcl_1 csc-frame csc-frame-invisible" id="c164813">
# <div class="tx-nbc2fe-incontent-column">
# <div class="nbc-right-float nbc-right-float-hide"><div class="introa_whole"><script type="text/javascript">
# 				var loading_1880722 = false; // loading indicator;
# 				var loading_num_1880722 = 0; // incrementing loading num;
#
# 				jQuery(document).ready(function() {
# 					//jQuery("img").unveil(200);
#
#
#
# 					/*
# 					jQuery(".introa_rl_hoverable").hover(function() {
# 						jQuery(this).children().children(".introa_rl_box").slideToggle(400); // if more than one element is on the page, this is attached more than once for each element
# 					});
# 					*/
#
#
# 				});
#
# 				function ajaxReload_1880722(tt_content_uid,page,items_per_page,no_url_change) {
#
# 					if (loading_1880722==true) { // do not call if already loading
# 						//jQuery("#introa_loading_info_1880722").html("already loading ...");
# 						//return false;
# 					}
#
# 					loading_1880722 = true;
#
# 					items_per_page = typeof items_per_page !== "undefined" ? items_per_page : 4;
#
# 					jQuery("#introa_ajax_"+tt_content_uid).html("loading ...");
# 					jQuery("#introa_ajax_"+tt_content_uid).show();
# 					jQuery("#introa_loading_info_"+tt_content_uid).html("loading ...");
# 					//console.log("loading "+items_per_page+" elements ...");
# 					jQuery("#introa_loading_info_"+tt_content_uid).show();
# ...
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Motorola-Moto-E4-Plus-Smartphone-Review.247658.0.html"><div class="introa_rm_img"><img alt="Motorola Moto E4 Plus" class="introa_img_small lazy" data-src="fileadmin/_processed_/3/c/csm_4_zu_3_Moto_E4_Plus_c0239e6f0f.jpg" data-src-retina="fileadmin/_processed_/3/c/csm_4_zu_3_Moto_E4_Plus_1555d3d18f.jpg" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Motorola Moto E4 Plus" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/3/c/csm_4_zu_3_Moto_E4_Plus_c0239e6f0f.jpg" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">79%</span></span> Motorola Moto E4 Plus Smartphone Review</h2></div></a><div class="introa_fulldate_background" style="width:5.4em;"> </div><div class="introa_fulldate" style="">Sep 12, 2017</div>
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Motorola-Moto-E4-Smartphone-Review.247644.0.html"><div class="introa_rm_img"><img alt="Lenovo Moto E4" class="introa_img_small lazy" data-src="fileadmin/_processed_/2/9/csm_4_zu_3_Moto_E4_e3159a463d.jpg" data-src-retina="fileadmin/_processed_/2/9/csm_4_zu_3_Moto_E4_b2fb6092b5.jpg" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Lenovo Moto E4" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/2/9/csm_4_zu_3_Moto_E4_e3159a463d.jpg" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">80%</span></span> Motorola Moto E4 Smartphone Review</h2></div></a><div class="introa_fulldate_background" style="width:5.4em;"> </div><div class="introa_fulldate" style="">Sep 7, 2017</div>
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Xiaomi-Mi-Max-2-Smartphone-Review.247162.0.html"><div class="introa_rm_img"><img alt="Xiaomi Mi Max 2 Smartphone Review" class="introa_img_small lazy" data-src="fileadmin/_processed_/c/a/csm_Teaser_4_3_4403681609.jpg" data-src-retina="fileadmin/_processed_/c/a/csm_Teaser_4_3_822f1def17.jpg" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Xiaomi Mi Max 2 Smartphone Review" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/c/a/csm_Teaser_4_3_4403681609.jpg" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">84%</span></span> Xiaomi Mi Max 2 Smartphone Review</h2></div></a><div class="introa_fulldate_background" style="width:5.4em;"> </div><div class="introa_fulldate" style="">Aug 30, 2017</div>
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Huawei-Y6-2017-Smartphone-Review.244992.0.html"><div class="introa_rm_img"><img alt="Huawei Y6 (2017)" class="introa_img_small lazy" data-src="fileadmin/_processed_/3/8/csm_4_zu_3_Huawei_Y6_c3ece0023e.jpg" data-src-retina="fileadmin/_processed_/3/8/csm_4_zu_3_Huawei_Y6_b21ecec981.jpg" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Huawei Y6 (2017)" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/3/8/csm_4_zu_3_Huawei_Y6_c3ece0023e.jpg" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">80%</span></span> Huawei Y6 2017 Smartphone Review</h2></div></a>
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Lenovo-Moto-C-Plus-Smartphone-Review.245786.0.html"><div class="introa_rm_img"><img alt="Lenovo Moto C Plus Smartphone Review" class="introa_img_small lazy" data-src="fileadmin/_processed_/e/e/csm_Teaser_592a12fb55.png" data-src-retina="fileadmin/_processed_/e/e/csm_Teaser_dce8ebe43c.png" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Lenovo Moto C Plus Smartphone Review" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/e/e/csm_Teaser_592a12fb55.png" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">80%</span></span> Lenovo Moto C Plus Smartphone Review</h2></div></a><div class="introa_fulldate_background" style="width:5.4em;"> </div><div class="introa_fulldate" style="">Aug 29, 2017</div>
# <a class="introa_small introa_review" href="https://www.notebookcheck.net/Lenovo-Moto-C-Smartphone-Review.244960.0.html"><div class="introa_rm_img"><img alt="Lenovo Moto C Smartphone Review" class="introa_img_small lazy" data-src="fileadmin/_processed_/7/b/csm_Teaser_fda350da4d.png" data-src-retina="fileadmin/_processed_/7/b/csm_Teaser_bba5423e3a.png" src="/fileadmin/templates/images/newsstream_logo.png"><noscript><img alt="Lenovo Moto C Smartphone Review" class="tx-nbc2fe-news-stream-image" height="45" src="fileadmin/_processed_/7/b/csm_Teaser_fda350da4d.png" width="60"/></noscript></img></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#83af4b; "><span class="average">77%</span></span> Lenovo Moto C Smartphone Review</h2></div></a><div style="margin-top:15px;text-align:center;clear:both"><a class="introa_page_buttons" href="https://www.notebookcheck.net/Reviews.55.0.html?&amp;page=-1" onclick="ajaxReload_1824503(1824503,1); jQuery('html, body').animate({scrollTop: jQuery('#introa_content_1824503').offset().top}, 2000); return false;">Next Page 〉</a></div>
#
#
#
# <div id="nbc_belowcontent"><div class="tx-nbc2fe-pi1">
# <div class="socialarea"><div class="socialarea_introtext">Please share our article, every link counts!</div><a class="socialarea_facebook" href="http://facebook.com/share.php?u=http%3A%2F%2Fwww.notebookcheck.net%2FReviews.55.0.html&amp;t=Reviews" target="_BLANK" title="Click to share this post on Facebook"><svg class="share_logo" enable-background="new 0 0 266.893 266.895" height="20px" version="1.1" viewbox="0 0 266.893 266.895" width="20px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <path d="M182.409,262.307v-99.803h33.499l5.016-38.895h-38.515V98.777c0-11.261,3.127-18.935,19.275-18.935  l20.596-0.009V45.045c-3.562-0.474-15.788-1.533-30.012-1.533c-29.695,0-50.025,18.126-50.025,51.413v28.684h-33.585v38.895h33.585  v99.803H182.409z" fill="#FFFFFF" id="f"></path>
# </svg></a> <a class="socialarea_twitter" href="https://twitter.com/intent/tweet?text=Reviews&amp;url=http%3A%2F%2Fwww.notebookcheck.net%2FReviews.55.0.html" target="_BLANK" title="Click to share this post on Twitter"><svg class="share_logo" enable-background="new 0 0 56.693 56.693" height="24px" version="1.1" viewbox="0 0 56.693 56.693" width="24px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M52.837,15.065c-1.811,0.805-3.76,1.348-5.805,1.591c2.088-1.25,3.689-3.23,4.444-5.592c-1.953,1.159-4.115,2-6.418,2.454  c-1.843-1.964-4.47-3.192-7.377-3.192c-5.581,0-10.106,4.525-10.106,10.107c0,0.791,0.089,1.562,0.262,2.303  c-8.4-0.422-15.848-4.445-20.833-10.56c-0.87,1.492-1.368,3.228-1.368,5.082c0,3.506,1.784,6.6,4.496,8.412  c-1.656-0.053-3.215-0.508-4.578-1.265c-0.001,0.042-0.001,0.085-0.001,0.128c0,4.896,3.484,8.98,8.108,9.91  c-0.848,0.23-1.741,0.354-2.663,0.354c-0.652,0-1.285-0.063-1.902-0.182c1.287,4.015,5.019,6.938,9.441,7.019  c-3.459,2.711-7.816,4.327-12.552,4.327c-0.815,0-1.62-0.048-2.411-0.142c4.474,2.869,9.786,4.541,15.493,4.541  c18.591,0,28.756-15.4,28.756-28.756c0-0.438-0.009-0.875-0.028-1.309C49.769,18.873,51.483,17.092,52.837,15.065z" fill="white"></path></svg></a> <a class="socialarea_reddit" href="https://www.reddit.com/submit?url=http%3A%2F%2Fwww.notebookcheck.net%2FReviews.55.0.html&amp;title=Reviews" target="_BLANK" title="Click to share this post on Reddit"><svg class="share_logo" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg"><g><circle cx="10" cy="10" fill="#FF4500" r="10"></circle><path d="M16.67,10A1.46,1.46,0,0,0,14.2,9a7.12,7.12,0,0,0-3.85-1.23L11,4.65,13.14,5.1a1,1,0,1,0,.13-0.61L10.82,4a0.31,0.31,0,0,0-.37.24L9.71,7.71a7.14,7.14,0,0,0-3.9,1.23A1.46,1.46,0,1,0,4.2,11.33a2.87,2.87,0,0,0,0,.44c0,2.24,2.61,4.06,5.83,4.06s5.83-1.82,5.83-4.06a2.87,2.87,0,0,0,0-.44A1.46,1.46,0,0,0,16.67,10Zm-10,1a1,1,0,1,1,1,1A1,1,0,0,1,6.67,11Zm5.81,2.75a3.84,3.84,0,0,1-2.47.77,3.84,3.84,0,0,1-2.47-.77,0.27,0.27,0,0,1,.38-0.38A3.27,3.27,0,0,0,10,14a3.28,3.28,0,0,0,2.09-.61A0.27,0.27,0,1,1,12.48,13.79Zm-0.18-1.71a1,1,0,1,1,1-1A1,1,0,0,1,12.29,12.08Z" fill="#FFF"></path></g></svg></a> <a class="socialarea_pocket" href="https://getpocket.com/save?url=http%3A%2F%2Fwww.notebookcheck.net%2FReviews.55.0.html" target="_BLANK" title="Read later with Pocket"><svg class="share_logo" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M 7 5 C 5.355469 5 4 6.355469 4 8 L 4 15 C 4 21.617188 9.382813 27 16 27 C 22.617188 27 28 21.617188 28 15 L 28 8 C 28 6.355469 26.644531 5 25 5 Z M 7 7 L 25 7 C 25.566406 7 26 7.433594 26 8 L 26 15 C 26 20.535156 21.535156 25 16 25 C 10.464844 25 6 20.535156 6 15 L 6 8 C 6 7.433594 6.433594 7 7 7 Z M 10.65625 11.40625 C 10.273438 11.40625 9.886719 11.582031 9.59375 11.875 C 9.007813 12.460938 9.007813 13.382813 9.59375 13.96875 L 15 19.375 C 15.28125 19.65625 15.664063 19.8125 16.0625 19.8125 C 16.460938 19.8125 16.84375 19.65625 17.125 19.375 L 22.40625 14.125 C 22.992188 13.539063 22.992188 12.585938 22.40625 12 C 21.820313 11.414063 20.867188 11.414063 20.28125 12 L 16.0625 16.21875 L 11.71875 11.875 C 11.425781 11.582031 11.039063 11.40625 10.65625 11.40625 Z " style=" "></path></svg></a> <a class="socialarea_flipboard" href="https://share.flipboard.com/bookmarklet/popout?v=2&amp;title=Reviews&amp;url=http%3A%2F%2Fwww.notebookcheck.net%2FReviews.55.0.html" target="_BLANK" title="Share on Flipboard"><svg class="logo" height="40" viewbox="0 0 100 100" width="40"><g fill="none" id="Page-1" stroke="none"><g fill="#F52828" id="Flipboard_01_Lockup"><path d="M0,0 L0,100 L100,100 L100,0 L0,0 Z M80,40 L60,40 L60,60 L40,60 L40,80 L20,80 L20,20 L80,20 L80,40 Z" id="Shape"></path></g></g></svg></a> <a class="socialarea_pocket" href="/cdn-cgi/l/email-protection#95e1f0e6e1d5e1f0e6e1bbf6faf8aae6e0f7fff0f6e1a8c7f0e3fcf0e2e6b3f7faf1eca8dbfae1f0f7fafafef6fdf0f6feafb5c7f0e3fcf0e2e6b0a5d4fde1e1e5b0a6d4b0a7d3b0a7d3e2e2e2bbfbfae1f0f7fafafef6fdf ...
# </div>
# <div style="padding: 3px; color: rgb(100, 100, 100);">&gt; <a href="Notebook-Laptop-Reviews-and-News.48.0.html">Notebook / Laptop Reviews and News</a> &gt; Reviews <br/></div><div style="padding: 3px; color: rgb(100, 100, 100);">Notebookcheck, 2005-09-12 (Update: 2019-11-20)</div><div id="snhb-bottom-multi-0"></div>
# <span class="bt-uid-tg" data-uid="5aec822ac9-158" style="display: none !important"></span>
# <div id="div-gpt-ad-1414573626553-3" style="text-align:center;margin:5px 0">
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-3'); });
# </script>
# </div></div>
#
# <br style="clear: both"/>
# <span> </span>
#
# <div id="nbc_bottombar"><div id="footer"><a href="http://www.notebookcheck.com/">Deutsch</a> |
# <a href="http://www.notebookcheck.net/">English</a> |
# <a href="http://www.notebookcheck.org/">Español</a> |
# <a href="http://www.notebookcheck.biz/">Français</a> |
# <a href="http://www.notebookcheck.it/">Italiano</a> |
# <a href="http://www.notebookcheck.nl/">Nederlands</a> |
# <a href="http://www.notebookcheck.pl/">Polski</a> |
# <a href="http://www.notebookcheck.info/">Português</a> |
# <a href="http://www.notebookcheck-ru.com/">Русский</a> |
# <a href="http://www.notebookcheck-tr.com/">Türkçe</a> |
# <a href="http://www.notebookcheck.se/">Svenska</a><span id="ccpa_link" style="display:none;color:#999;font-size:0.8em"> | Do Not Sell My Personal Information</span>
# <script>
# __uspapi('setUSPLink', 1, function() {}, "ccpa_link");
# </script> <span style="font-size:0.7em;color:#bbb"> | 20:36 06.10</span><div id="div-gpt-ad-1414573626553-13" style="text-align:center;margin-top:10px">
# <script>
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1414573626553-13'); });
# </script>
# </div><div id="amzn-assoc-ad-2d00b6ec-031d-4711-bdb7-e4d8c615b3e3"></div><script async="" src="//z-na.amazon-adsystem.com/widgets/onejs?MarketPlace=US&amp;adInstanceId=2d00b6ec-031d-4711-bdb7-e4d8c615b3e3"></script><script src="https://www.notebookcheck.com/ads.v5.js?v=3"></script><script>var ab_cl = new XMLHttpRequest();</script><script>var ab_ubl = true;
# if (!document.getElementById("AAdsspaCe")) {
# 	var el = document.getElementById("nbc_contentcontainer");
# 	elChild = document.createElement("div");
# 	elChild.style.cssText = "border:2px solid #999;padding:2px;font-style:italic;color:#999";
# 	elChild.innerHTML = "Independent journalism is made possible by advertising. We show the least amount of ads whenever possible but we intentionally show more ads when an ad-blocker is used. Please, switch off ad blockers and support us!";
# 	el.insertBefore(elChild, el.firstChild);
# 	ab_cl.open("GET", "/fileadmin/Sonstiges/ama_ab_us_smartphone.html?v=3");
# 	ab_cl.onreadystatechange = function() {
# 	if (this.readyState == 4 && this.status == 200) {
# 		elChild2 = document.createElement("div");
# 		elChild2.style.cssText = "overflow: hidden;";
# 		elChild2.innerHTML = ab_cl.responseText;
# 		el.insertBefore(elChild2, el.firstChild);
#
# 		elChild3 = document.createElement("div");
# 		elChild3.style.cssText = "overflow: hidden;";
# 		elChild3.innerHTML = ab_cl.responseText;
# 		var el2 = document.getElementById("nbc_bottombar");
# 		el2.insertBefore(elChild3, el2.firstChild);
# 	}
# 	}
# 	ab_cl.send();
# 	console.log("a loaded");
# } else console.log("AAdsspaCe found");</script><script>var _0x5a65=['readyState','log','style','cssText','onreadystatechange','ubnotfound','send','undefined','overflow: hidden;','/fileadmin/Sonstiges/ama_ab_us_smartphone.html?v=3','open','responseText','status','div','GET','createElement','querySelectorAll','firstChild'];(function(_0x4ec9e9,_0x5a65a2){var _0x44e5f9=function(_0x430d56){while(--_0x430d56){_0x4ec9e9['push'](_0x4ec9e9['shift']());}};_0x44e5f9(++_0x5a65a2);}(_0x5a65,0x1af));var _0x44e5=function(_0x4ec9e9,_0x5a65a2){_0x4ec9e9=_0x4ec9e9-0x0;var _0x44e5f9=_0x5a65[_0x4ec9e9];return _0x44e5f9;};if(typeof ab_ubl!==_0x44e5('0x8'))console['log'](_0x44e5('0x6'));else console[_0x44e5('0x2')]('ubtest'),ab_cl[_0x44e5('0xb')](_0x44e5('0xf'),_0x44e5('0xa')),ab_cl[_0x44e5('0x5')]=function(){if(this[_0x44e5('0x1')]==0x4&&this[_0x44e5('0xd')]==0xc8){var _0x3fe235=document[_0x44e5('0x11')]('p')[0x0];elChild2=document[_0x44e5('0x10')](_0x44e5('0xe')),elChild2[_0x44e5('0x3')][_0x44e5('0x4')]=_0x44e5('0x9'),elChild2['innerHTML']=ab_cl[_0x44e5('0xc')],_0x3fe235['insertBefore'](elChild2,_0x3fe235[_0x44e5('0x0')]);}},ab_cl[_0x44e5('0x7')]();</script></div></div>

# %%
# get all links 'a' with class 'introa_review',
# using the BeautifulSoup findAll command
links = soup.findAll('a', {'class': 'introa_review'})

# %%
# check number of links found
len(links)
# Out:
# 500

# %%
# print first link
links[0]
# Out:
# <a class="introa_large introa_review" href="https://www.notebookcheck.net/Samsung-Galaxy-Note20-Review-Not-always-better-than-the-Note10.496540.0.html"><article><div class="introa_rm_img"><img alt="Samsung Galaxy Note20 Review - Not always better than the Note10" class="introa_img_large lazy" data-src="fileadmin/_processed_/f/b/csm_4_zu_3_Teaser_Samsung_Galaxy_Note20_8257_99e63366fd.jpg" data-src-retina="fileadmin/_processed_/f/b/csm_4_zu_3_Teaser_Samsung_Galaxy_Note20_8257_53e0deb6ef.jpg" src="fileadmin/_processed_/f/b/csm_4_zu_3_Teaser_Samsung_Galaxy_Note20_8257_99e63366fd.jpg"/></div><div class="introa_rm_text"><h2 class="introa_title"><span class="rating" style="color:#4baf4e; "><span class="average">88%</span></span> Samsung Galaxy Note20 Review - Not always better than the Note10</h2><div class="introa_rm_abstract"><b>Dimmed.</b> The Samsung Galaxy Note20 is more than $300 less than the Ultra model. Looking at the specs sheet we can spot a few cut corners, but it is not immediately clear whether or not the more expensive Note20 is really worth its premium or, more importantly, whether the Note20 worth switching to from the Note10.<br/><span class="introa_review_specs_med">Samsung Exynos 990 | ARM Mali-G77 MP11 | 6.7" | 192 g</span><div class="itemauthordate">Daniel Schmidt, <span class="itemdate itemdate_1601675220" title="Fri, 02 Oct 2020 23:47:00 +0200">Fri, 02 Oct 2020 23:47:00 +0200<script>convertTime("1601675220");</script></span></div></div></div></article></a>

# %% [markdown]
# For every link, it stored everything within `<a` and `</a>`, while we just want the url stored in `href`.
# Let's use a for-loop, to loop over all links in variable links, to then for every link in links select only the href. :)

# %%
# create empty list to store href's in
reviewLinks = []

# loop over all links in links
for i in links:
    # select href, save to url
    url = i['href']
    # write url to new list
    reviewLinks.append(url)

# %%
# check if it worked, print first 5 reviewLinks
reviewLinks[:5]
# Out:
# ['https://www.notebookcheck.net/Samsung-Galaxy-Note20-Review-Not-always-better-than-the-Note10.496540.0.html',
#  'https://www.notebookcheck.net/Xiaomi-Redmi-10X-5G-Smartphone-Review-Faster-than-a-Samsung-Galaxy-S20-Ultra.496414.0.html',
#  'https://www.notebookcheck.net/Blu-G90-Smartphone-Review-USA-Cell-Phone-with-Triple-Camera.496256.0.html',
#  'https://www.notebookcheck.net/LG-K51S-Smartphone-Review-Too-little-too-late.495712.0.html',
#  'https://www.notebookcheck.net/Samsung-Galaxy-M21-Smartphone-Review-Plain-but-good.495326.0.html']

# %%
# check if it worked, print length reviewLinks
len(reviewLinks)
# Out:
# 500

# %% [markdown]
# ## collect dat (2nd scraper)
#
# **Goal**
# For every device we now have a url of, get the data we want.
#
# Ok, how are we gonna go about this?
# ...
# ...
# ...
# ...
# ...
# Off course, let's use another for loop. ;)
#
# For every url in the list named reviewLinks:
# - request the webpage;
# - create a soup of said webpage;
# - select the needed data from that soup;
# - write that data to a csv.
#
# Let's try all of the above for 1 webpage first.

# %%
# request webpage, save result to r
r = requests.get(reviewLinks[0], timeout=5)
r.status_code
# Out:
# 200

# %%
# create a soup of the content of the request
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# select devicename from soup
name = soup.find('div', {'class': 'specs_header'}).text.strip()
name
# Out:
# 'Samsung\xa0Galaxy Note20 (Galaxy Note Series)'

# %% [markdown]
# `\xa0` is a non-breaking space in Latin1 (ISO 8859-1); so 'Samsung\xa0Galaxy Note20 (Galaxy Note Series)' includes some unicode encoding that showed up on the surface. By using the Python unicode library, this is easily fixed. `unicodedata.normalize('NFKD', text_string)`

# %%
# select devicename from soup
name = unicodedata.normalize("NFKD", soup.find('div', {'class': 'specs_header'}).text)
name
# Out:
# 'Samsung Galaxy Note20 (Galaxy Note Series)'

# %%
# select the auto analysis from the soup
aa = soup.find('div', {'class': 'auto_analysis'})
aa
# Out:
# <div class="auto_analysis" style="display:inline-block;width:218px"><div style="margin-bottom:3px;">X-Rite i1Pro 2</div>Maximum: 637 cd/m² Average: 620.6 cd/m² Minimum: 1.52 cd/m²<br/>Brightness Distribution: 95 %<br/><span style="">Center on Battery: 610 cd/m²</span><br/>Contrast: ∞:1 (Black: 0 cd/m²)<br/>ΔE Color 2.4 | 0.6-29.43 Ø5.8<br/>ΔE Greyscale 2.8 | 0.64-98 Ø6<br/>99.9% sRGB (Calman 2D) <br/>Gamma: 2.09</div>

# %%
aaClean = unicodedata.normalize("NFKD", aa.text)
aaClean
# Out:
# 'X-Rite i1Pro 2Maximum: 637 cd/m2 Average: 620.6 cd/m2 Minimum: 1.52 cd/m2Brightness Distribution: 95 %Center on Battery: 610 cd/m2Contrast: ∞:1 (Black: 0 cd/m2)ΔE Color 2.4 | 0.6-29.43 Ø5.8ΔE Greyscale 2.8 | 0.64-98 Ø699.9% sRGB (Calman 2D) Gamma: 2.09'

# %%
# use regex to find all data needed in aaClean
matches = re.findall(r'([A-Za-z]+\:\s[0-9\.|&nbsp;|cd\/m2]+)', aaClean)
matches
# Out:
# ['Maximum: 637',
#  'Average: 620.6',
#  'Minimum: 1.52',
#  'Distribution: 95',
#  'Battery: 610',
#  'Black: 0',
#  'Gamma: 2.09']

# %% [markdown]
# We now have a list named `matches`, for which we like to split every list-item on the `:` in there. This way we can create a dictionary, and easily write the data to a csv.

# %%
# create an empty list [] that contains a dictionary {}
result = [{}]
# for every item in matches
for m in matches:
    # split item on : into key and value
    key, val = m.split(":", 1)
    # save key and value to list
    if key in result[-1]:
        result.append({})
    result[-1][key] = val.strip()
    
result
# Out:
# [{'Maximum': '637',
#   'Average': '620.6',
#   'Minimum': '1.52',
#   'Distribution': '95',
#   'Battery': '610',
#   'Black': '0',
#   'Gamma': '2.09'}]

# %% [markdown]
# Now all that's left to do is to collect all code below, and write the data to a csv...

# %%
# while it might sound counter-intuitive, we're starting by creating an empty csv
# this way we create a file to write the data we collect later to
# first, let's name csvColumns to be used in our csv-file
csvColumns = ['device',
              'url',
              'Maximum',
              'Average',
              'Minimum',
              'Distribution',
              'Battery',
              'Black',
              'Gamma',
              'Contrast', 
              'calibrated']

# now, let's create a csv file named 'data.csv'
with open('data.csv', 'w+') as file:
    # we're going to be writing a Python dictionary to the csv, hence this writer
    writer = csv.DictWriter(file, fieldnames=csvColumns)
    # write the header to the csv already 
    writer.writeheader()
    
    # now let's loop over all urls in the list
    for i in reviewLinks:
        # request webpage, save result to r
        r = requests.get(i, timeout=5)
        # if request is 200, and thus did not fail...
        if r.status_code == 200:
            # create a soup of the content of the request
            soup = BeautifulSoup(r.content, 'html.parser')
            # select name from soup
            # we're using try and except here, so when things don't work out
            # our scraper will continue setting name to none instead of breaking
            try:
                name = unicodedata.normalize("NFKD", soup.find('div', {'class': 'specs_header'}).text)
            except:
                name = None
            # parse auto analysis (aa) data from it
            # again, try and except so incase it doesn't work our scraper can continue
            # because it knows what to do when an exception occurs
            try:
                aa = soup.find('div', {'class': 'auto_analysis'})
                aaClean = unicodedata.normalize("NFKD", aa.text)
                # use regex to select data 
                matches = re.findall(r'([A-Za-z]+\:\s[0-9\.|&nbsp;|cd\/m2]+)', aaClean)
            except:
                matches = None
            # create an empty dictionary {} named result
            result = {}
            # for every item in matches
            # again, using try and except...
            try:
                # for every item (m) in matches...
                for m in matches:
                    # split item on : into key and value
                    key, val = m.split(":", 1)
                    # add both key and stripped value to dictionary result
                    result[key] = val.strip()
            except:
                # if an exceptions occur, continue
                continue
            # add name device to dict
            result['device'] = name
            # add url to dict
            result['url'] = i
            # write result to csv
            writer.writerow(result)
        # if the request fails (read: has not a 200 statuscode)
        else:
            print('Oh no! Something went wrong requesting ' + i)
